# %%
import os
os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-02-0086/')
# Out:
# ['T1', 'T2', 'CT1', 'RTSTRUCT', 'FLAIR', 'RTSTRUCT_DICOM']

# %%
import glob

glob.glob('/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-02-0086/')
# Out:
# ['/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-02-0086/']

# %%
for i in glob.glob('/anvar/public_datasets/preproc_study/gbm/dicom/*/*.json'):
#     os.remove(i)

# %% [markdown]
# ### 1. GBM repository

# %%
os.listdir('/anvar/public_datasets/preproc_study/gbm/1_reg/TCGA-06-0154/')
# Out:
# ['T2.nii.gz', 'FLAIR.nii.gz', 'T1.nii.gz', 'CT1_SEG.nii.gz', 'CT1.nii.gz']

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tqdm
import ants

path = '3c_n4_susan'

print('/home/kate/projects/qc_preprocessing/{}_gbm/'.format(path))
os.makedirs('/home/kate/projects/qc_preprocessing/{}_gbm/'.format(path), exist_ok = True)

def plot_qc(image, mask, patient_id):
    fig, axs = plt.subplots(3,3,figsize=(12,12))
    idx = np.argsort(mask.sum(axis=(0,1)))[-3:]
    for i in range(3):
        axs[i, 0].imshow(image[..., idx[i]], cmap='gray')
        axs[i, 1].imshow(mask[..., idx[i]], cmap='gray')
        axs[i, 2].imshow(image[..., idx[i]]+200*mask[..., idx[i]], cmap='gray')
    axs[0,0].set_title(patient_id)
    plt.tight_layout()
    plt.savefig(f'/home/kate/projects/qc_preprocessing/{path}_gbm/{patient_id}.png', dpi=300)
    plt.plot()
    plt.close(fig)

output = '/anvar/public_datasets/preproc_study/gbm/{}/'.format(path)

for patient in tqdm.tqdm(os.listdir(output)):
    try:
        im = ants.image_read(output + patient +'/CT1.nii.gz')
        mask = ants.image_read(output + patient +'/CT1_SEG.nii.gz')
        plot_qc(im, mask, patient_id=str(patient))
    except Exception as e:
        print(e, patient)
# Out:
#   0%|          | 0/35 [00:00<?, ?it/s]
# /home/kate/projects/qc_preprocessing/3c_n4_susan_gbm/
#   6%|▌         | 2/35 [00:08<02:17,  4.15s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     503     try:
# --> 504         fh = fp.fileno()
#     505         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3561051/3225686635.py in <module>
#      29         im = ants.image_read(output + patient +'/CT1.nii.gz')
#      30         mask = ants.image_read(output + patient +'/CT1_SEG.nii.gz')
# ---> 31         plot_qc(im, mask, patient_id=str(patient))
#      32     except Exception as e:
#      33         print(e, patient)
#
# /tmp/ipykernel_3561051/3225686635.py in plot_qc(image, mask, patient_id)
#      19     axs[0,0].set_title(patient_id)
#      20     plt.tight_layout()
# ---> 21     plt.savefig(f'/home/kate/projects/qc_preprocessing/{path}_gbm/{patient_id}.png', dpi=300)
#      22     plt.plot()
#      23     plt.close(fig)
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507         """
#     508         FigureCanvasAgg.draw(self)
# --> 509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/miniconda3/lib/python3.9/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1614         pil_kwargs.setdefault("format", format)
#    1615         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1616         image.save(fname, **pil_kwargs)
#    1617
#    1618
#
# ~/miniconda3/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2233
#    2234         try:
# -> 2235             save_handler(self, fp, filename)
#    2236         finally:
#    2237             # do what we can to clean up
#
# ~/miniconda3/lib/python3.9/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1347         _write_multiple_frames(im, fp, chunk, rawmode)
#    1348     else:
# -> 1349         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1350
#    1351     if info:
#
# ~/miniconda3/lib/python3.9/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     516             else:
#     517                 while True:
# --> 518                     l, s, d = e.encode(bufsize)
#     519                     fp.write(d)
#     520                     if s:
#
# KeyboardInterrupt:

# %%
base_dir = '/anvar/public_datasets/preproc_study/gbm/orig/'
list_patients = os.listdir(base_dir)

# %%
import ants
import pandas as pd
sizes_frame = pd.DataFrame(columns = ['id','t1_x', 't1_y', 't1_z', 't1c_x', 't1c_y', 't1c_z'])
import numpy as np
for i in list_patients:
    try:
        t1_size = np.shape(ants.image_read(base_dir + i + '/T1.nii.gz').numpy())
        t1c_size = np.shape(ants.image_read(base_dir + i + '/CT1.nii.gz').numpy())
        sizes_frame = sizes_frame.append(
        {'id': i,
        't1_x':t1_size[0],
        't1_y':t1_size[1],
        't1_z':t1_size[2],
        't1c_x':t1c_size[0],
        't1c_y':t1c_size[1],
        't1c_z':t1c_size[2]}, ignore_index=True
        )
    except:
        pass

# %%
sizes_frame
# Out:
#                id t1_x t1_y t1_z t1c_x t1c_y t1c_z
# 0    TCGA-02-0086  256  256   23   256   256    23
# 1    TCGA-02-0048  256  256   23   256   256    23
# 2    TCGA-02-0102  256  256   23   256   256    23
# 3    TCGA-02-0059  256  256  124   512   512    23
# 4    TCGA-02-0069  256  256   24   512   512   124
# ..            ...  ...  ...  ...   ...   ...   ...
# 126  TCGA-08-0352  256  256   44   256   256   124
# 127  TCGA-06-0142  256  256   56   256   256    56
# 128  TCGA-06-0648  512  512   36   512   512    71
# 129  TCGA-02-0037  256  256   23   256   256    23
# 130  TCGA-08-0520  256  256   44   256   256   124
#
# [131 rows x 7 columns]

# %%
sizes_frame['t1c_z'].hist()
# Out:
# <AxesSubplot:>

# %%
len(sizes_frame[(sizes_frame['t1_z'] >= sizes_frame['t1c_z'])])
# Out:
# 75

# %%
len(sizes_frame[(sizes_frame['t1_z'] <= sizes_frame['t1c_z'])])
# Out:
# 125

# %% [markdown]
# ### Delete repos with no mask:

# %%
tcia_folder = '/anvar/public_datasets/tcia/manifest-1588284345182/TCGA-GBM/'
list_masks = os.listdir(tcia_folder)
len(os.listdir(tcia_folder))
# Out:
# 103

# %%
len(os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/'))
# Out:
# 135

# %%
import shutil
for i in os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/'):
    if i not in list_masks:
        print(i)
        shutil.rmtree('/anvar/public_datasets/preproc_study/gbm/dicom/' + i, ignore_errors=True)
# Out:
# TCGA-02-0048
# TCGA-06-0168
# TCGA-06-0133
# TCGA-12-1602
# TCGA-06-0649
# TCGA-08-0354
# TCGA-08-0529
# TCGA-06-0213
# TCGA-06-0241
# TCGA-08-0357
# TCGA-08-0358
# TCGA-14-1829
# TCGA-02-0060
# TCGA-06-5412
# TCGA-08-0350
# TCGA-08-0521
# TCGA-14-0789
# TCGA-27-1838
# TCGA-08-0510
# TCGA-08-0524
# TCGA-06-0128
# TCGA-06-0166
# TCGA-27-2526
# TCGA-06-0132
# TCGA-08-0353
# TCGA-12-1093
# TCGA-27-1834
# TCGA-02-0003
# TCGA-06-0175
# TCGA-19-1390
# TCGA-06-0189
# TCGA-08-0352
# TCGA-06-0648

# %%
import pandas as pd

gbm_paths = pd.read_csv('gbm_paths.csv')

# %%
print(gbm_paths['T2'][gbm_paths['ID'] == 'TCGA-06-0182'].values)
# Out:
# [' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-06-0182/09-01-2002-MRI BRAIN WWO CONTRAS-96990/6.000000-AXIAL FSE-19198']

# %%
print(gbm_paths['FLAIR'][gbm_paths['ID'] == 'TCGA-06-0182'].values)
# Out:
# [' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-06-0182/09-01-2002-MRI BRAIN WWO CONTRAS-96990/7.000000-AxFLAIR-thin for surgery-31783']

# %%
os.listdir(tcia_gbm_raw + 'TCGA-06-0182' + '/09-01-2002-MRI BRAIN WWO CONTRAS-96990' )
# Out:
# ['7.000000-AxFLAIR-thin for surgery-31783',
#  '6.000000-AXIAL FSE-19198',
#  '9.000000-AXIAL T1-13082',
#  '13.000000-AxT1-thin for surgery-12089']

# %% [markdown]
# ### Double check the for right modalities

# %%
1. удалить нии
2. сохранить новые нии
3. удалить лишние директории из диком
3* проверить на сайте маски
4. переименовать Ct1 c буквой
5. просмотреть глазами
6. просмотреть список анвара
7. повторить для lgg
8. сохранить регистрацию


1. скопировать чуваков (их нет на уранусе, попрошу Влада)
2. пересохранить два файла (есть)
3. удалить лишний нейминг 
4. проверить файлы по названию

# %%
gbm_paths['T1C'][gbm_paths['ID'] == 'TCGA-12-0616'] = ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-12-0616/04-12-1999-Routine Brain-03138/8.000000-cor mprage c-81607'

# %%
import glob2
glob2.glob('/anvar/public_datasets/tcia/**/*filepart*')
# Out:
# ['/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-02-0075/09-24-1999-MRI BRAIN WWO CONTRAST-32875/17.000000-Ax SE T1 Post-08723/1-01.dcm.filepart',
#  '/anvar/public_datasets/tcia/manifest-25ZdsnMy5264093150469993200/TCGA-LGG/TCGA-DU-A5TP/06-14-1997-MRI BRAIN WWO CONTRAST-14542/8.000000-DTI 2.6mm WH-90495/1-0340.dcm.filepart',
#  '/anvar/public_datasets/tcia/training_data/TCGA-02-0075/CT1/1-01.dcm.filepart']

# %%
shutil.rmtree('/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-12-0616/CT1')
shutil.copytree('/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-12-0616/04-12-1999-Routine Brain-03138/8.000000-cor mprage c-81607', 
                '/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-12-0616/CT1')
# Out:
# '/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-12-0616/CT1'

# %%
cp /anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-02-0075/09-24-1999-MRI\ BRAIN\ WWO\ CONTRAST-32875/17.000000-Ax\ SE\ T1\ Post-08723/1-01.dcm /anvar/public_datasets/preproc_study/gbm/dicom/TCGA-02-0075/CT1

# %%
/anvar/public_datasets/tcia/manifest-25ZdsnMy5264093150469993200/TCGA-LGG/TCGA-DU-A5TP/06-14-1997-MRI\ BRAIN\ WWO\ CONTRAST-14542/8.000000-DTI\ 2.6mm\ WH-90495/

# %%
dcm2niix -b n -f CT1 -z y -o /data/orig/TCGA-02-0075/ /data/dicom/TCGA-02-0075/CT1/

# %%
dcm2niix -b n -f CT1 -z y -o /data/orig/TCGA-12-0616/ /data/dicom/TCGA-12-0616/CT1/

# %%
os.remove('/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/CT1.nii.gz')
# dcm2niix -b n -f CT1 -z y -o /data/orig/TCGA-06-0646/ /data/dicom/TCGA-06-0646/CT1/

# %%
gbm_paths['T1C'][gbm_paths['ID'] == 'TCGA-76-6282'] = ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6282/08-24-1998-JHN BRAIN COMBO IP-22866/5.000000-BRAINSTRYKERT2AXDOUBLE-70745'

# %%
shutil.rmtree('/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-76-6282/CT1')
shutil.copytree('/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6282/08-24-1998-JHN BRAIN COMBO IP-22866/5.000000-BRAINSTRYKERT2AXDOUBLE-70745', 
                '/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-76-6282/CT1')
# Out:
# '/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-76-6282/CT1'

# %%
os.remove('/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/CT1.nii.gz')
#dcm2niix -b n -f CT1 -z y -o /data/orig/TCGA-76-6282/ /data/dicom/TCGA-76-6282/CT1/

# %%
gbm_paths['T1C'][gbm_paths['ID'] == 'TCGA-76-6193'] = ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175/9.000000-BRAINSTRYKERAX-RAGE-STRY-89080'

# %%
shutil.rmtree('/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-76-6193/CT1')
shutil.copytree('/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175/9.000000-BRAINSTRYKERAX-RAGE-STRY-89080', 
                '/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-76-6193/CT1')
# Out:
# '/anvar/public_datasets/preproc_study/gbm/dicom/TCGA-76-6193/CT1'

# %%
os.remove('/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/CT1.nii.gz')
# dcm2niix -b n -f CT1 -z y -o /data/orig/TCGA-76-6193/ /data/dicom/TCGA-76-6193/CT1/

# %%
os.listdir('/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'T2_e1.nii.gz',
#  'CT1.json',
#  'T1.nii.gz',
#  'T2_e2.json',
#  'T1.json',
#  'CT1.nii.gz',
#  'FLAIR.json',
#  'T2_e1.json']

# %%
gbm_paths.to_csv('gbm_paths.csv')

# %% [markdown]
# ### list to check

# %%
list_double_check = ['TCGA-08-0354', 'TCGA-12-0616', 'TCGA-76-6282', 'TCGA-27-1838', 'TCGA-76-6193', 'TCGA-02-0075', 'TCGA-12-0616', 'TCGA-76-6282', 'TCGA-08-0512', 'TCGA-76-6193']
tcia_lgg_raw = '/anvar/public_datasets/tcia/manifest-25ZdsnMy5264093150469993200/TCGA-LGG/'
tcia_gbm_raw = '/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/'
len(os.listdir(tcia_lgg_raw)),len(os.listdir(tcia_gbm_raw))
# Out:
# (67, 136)

# %%
os.listdir('/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'T2_e1.nii.gz',
#  'CT1.json',
#  'T1.nii.gz',
#  'T2_e2.json',
#  'T1.json',
#  'CT1.nii.gz',
#  'FLAIR.json',
#  'T2_e1.json']

# %%
print(gbm_paths[gbm_paths['ID'] == 'TCGA-76-6193'].values)
# Out:
# [[95 'TCGA-76-6193'
#   ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175/10.000000-BRAINSTRYKERt1AX-91010'
#   ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175/10.000000-BRAINSTRYKERt1AX-91010'
#   ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175/7.000000-BRAINCONTRASTDOUBLEECHO-99899/'
#   ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175/4.000000-BRAINNONCONTRASTFLAIRA-83981']]

# %%
os.listdir('/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175')
# Out:
# ['4.000000-BRAINNONCONTRASTFLAIRA-83981',
#  '9.000000-BRAINSTRYKERAX-RAGE-STRY-89080',
#  '7.000000-BRAINCONTRASTDOUBLEECHO-99899',
#  '10.000000-BRAINSTRYKERt1AX-91010']

# %%
ants.plot(ants.image_read('/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/CT1.nii.gz'))

# %%
ants.plot(ants.image_read(base_dir + 'TCGA-06-0162/T2_e1.nii.gz'))

# %%
ants.plot(ants.image_read(base_dir + 'TCGA-06-0162/T2_e1a.nii.gz'))

# %%
t2_e2_list = glob.glob(base_dir+'/*/T2_e2*.nii.gz')

for j in [i.split('T2_e2')[0] for i in t2_e2_list]:
    os.rename(j + 'T2_e2.nii.gz', j + 'T2.nii.gz')

# %%
t2_real_list = glob.glob(base_dir+'/*/T2_real.nii.gz')

for j in [i.split('T2_real')[0] for i in t2_real_list]:
    os.rename(j + 'T2_real.nii.gz', j + 'T2.nii.gz')

# %%
t1_real_list = glob.glob(base_dir+'/*/T1_real.nii.gz')

for j in [i.split('T1_real')[0] for i in t1_real_list]:
    os.rename(j + 'T1_real.nii.gz', j + 'T1.nii.gz')

# %%
t2_e1a_list = glob.glob(base_dir+'/*/T2_e1a.nii.gz')

for j in [i.split('T2_e1a')[0] for i in t2_e1a_list]:
    os.rename(j + 'T2_e1a.nii.gz', j + 'T2.nii.gz')

# %%
ct1_e1b_list = glob.glob(base_dir+'/*/CT1_e2.nii.gz')

for j in [i.split('CT1_e2')[0] for i in ct1_e1b_list]:
    os.rename(j + 'CT1_e2.nii.gz', j + 'CT1.nii.gz')

# %%
flair_real_list = glob.glob(base_dir+'/*/FLAIR_real.nii.gz')

for j in [i.split('FLAIR_real')[0] for i in flair_real_list]:
    os.rename(j + 'FLAIR_real.nii.gz', j + 'FLAIR.nii.gz')

# %%
os.listdir(base_dir + 'TCGA-08-0512')
# Out:
# ['T1.nii.gz', 'T1.json']

# %%
import ants
for i in list_masks:
#     print(i)
    try:
        t1 = ants.image_read(base_dir + i + '/T1.nii.gz')
        t1c = ants.image_read(base_dir + i + '/CT1.nii.gz')
        t2 = ants.image_read(base_dir + i + '/T2.nii.gz')
        flair = ants.image_read(base_dir + i + '/FLAIR.nii.gz')
    except Exception as e:
        print(e)
        pass
# Out:
# File /anvar/public_datasets/preproc_study/gbm/orig/license.html/T1.nii.gz does not exist!

# %%
ants.plot(ants.image_read(base_dir + 'TCGA-76-6282/CT1_e2.nii.gz'))

# %%
os.listdir('/anvar/public_datasets/tcia/manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-76-6193/06-02-2001-MRI BRAIN STRYKER JHN IP-60175')
# Out:
# ['4.000000-BRAINNONCONTRASTFLAIRA-83981',
#  '9.000000-BRAINSTRYKERAX-RAGE-STRY-89080',
#  '7.000000-BRAINCONTRASTDOUBLEECHO-99899',
#  '10.000000-BRAINSTRYKERt1AX-91010']

# %%
gbm_paths.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'T1', 'T1C', 'T2', 'FLAIR'], dtype='object')

# %%
gbm_paths[gbm_paths['ID'] == 'TCGA-02-0075'].values
# Out:
# array([[25, 'TCGA-02-0075',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-02-0075/09-24-1999-MRI BRAIN WWO CONTRAST-32875/14.000000-FSPGR 3D-90164',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-02-0075/09-24-1999-MRI BRAIN WWO CONTRAST-32875/17.000000-Ax SE T1 Post-08723',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-02-0075/09-24-1999-MRI BRAIN WWO CONTRAST-32875/10.000000-FSE T2-35736',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-02-0075/09-24-1999-MRI BRAIN WWO CONTRAST-32875/11.000000-T2 FLAIR-76096']],
#       dtype=object)

# %% [markdown]
# ## Check naming

# %%
metadata = pd.read_csv('metadata.csv')

# %%
metadata['File Location'][0]
# Out:
# '.\\TCGA-GBM\\TCGA-02-0006\\08-23-1996-MRI BRAIN W WO CONTRAMR-42545\\300.000000-AX T1 Glioma Segmentation Corrected-61527'

# %%
metadata['Series Description'].value_counts()
# Out:
# AXIAL FLAIR Glioma Segmentation                      40
# AXIAL FLAIR Glioma Segmentation Corrected            38
# AX T1 POST GD FLAIR Glioma Segmentation              33
# AX T2 FR-FSE RF2 150 Glioma Segmentation             33
# AX T1 pre gd Glioma Segmentation                     33
#                                                      ..
# STROKE     FLAIR Glioma Segmentation                  1
# SEIZURE    T2 GRASE Glioma Segmentation Corrected     1
# Brain      T1WSE Glioma Segmentation Corrected        1
# STROKE     FLAIR Glioma Segmentation Corrected        1
# 3D AXIALIRSPGRFast Glioma Segmentation Corrected      1
# Name: Series Description, Length: 367, dtype: int64

# %%
# os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/')

# %%
import pydicom
from pydicom import dcmread

temp_list = os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/' + gbm_paths['ID'].iloc[0] + '/T1/')
dcmread('/anvar/public_datasets/preproc_study/gbm/dicom/' +\
        gbm_paths['ID'].iloc[0] + '/T1/' + temp_list[0]).StudyInstanceUID
# Out:
# '1.3.6.1.4.1.14519.5.2.1.1706.4001.278960043528371206673900239956'

# %%
gbm_paths['FLAIR'][gbm_paths['ID'] == 'TCGA-06-0182'].values
# Out:
# array([' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-06-0182/09-01-2002-MRI BRAIN WWO CONTRAS-96990/7.000000-AxFLAIR-thin for surgery-31783'],
#       dtype=object)

# %%
metadata[metadata['Subject ID'] == 'TCGA-02-0006']
# Out:
#                                           Series UID Collection  \
# 0  1.2.276.0.7230010.3.1.3.8323329.363456.1540933...   TCGA-GBM
# 1  1.2.276.0.7230010.3.1.3.8323329.363425.1540933...   TCGA-GBM
# 2  1.2.276.0.7230010.3.1.3.8323329.363465.1540933...   TCGA-GBM
# 3  1.2.276.0.7230010.3.1.3.8323329.363974.1540933...   TCGA-GBM
# 4  1.2.276.0.7230010.3.1.3.8323329.363423.1540933...   TCGA-GBM
# 5  1.2.276.0.7230010.3.1.3.8323329.363999.1540933...   TCGA-GBM
# 6  1.2.276.0.7230010.3.1.3.8323329.363998.1540933...   TCGA-GBM
# 7  1.2.276.0.7230010.3.1.3.8323329.364017.1540933...   TCGA-GBM
#
#   3rd Party Analysis                        Data Description URI  \
# 0                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 1                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 2                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 3                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 4                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 5                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 6                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# 7                yes  https://doi.org/10.7937/TCIA.2018.ow6ce3ml
#
#      Subject ID                                          Study UID  \
# 0  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 1  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 2  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 3  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 4  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 5  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 6  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# 7  TCGA-02-0006  1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
#
#          Study Description  Study Date  \
# 0  MRI BRAIN W WO CONTRAMR  08-23-1996
# 1  MRI BRAIN W WO CONTRAMR  08-23-1996
# 2  MRI BRAIN W WO CONTRAMR  08-23-1996
# 3  MRI BRAIN W WO CONTRAMR  08-23-1996
# 4  MRI BRAIN W WO CONTRAMR  08-23-1996
# 5  MRI BRAIN W WO CONTRAMR  08-23-1996
# 6  MRI BRAIN W WO CONTRAMR  08-23-1996
# 7  MRI BRAIN W WO CONTRAMR  08-23-1996
#
#                          Series Description Manufacturer Modality  \
# 0       AX T1 Glioma Segmentation Corrected        QIICR      SEG
# 1    AX FLAIR Glioma Segmentation Corrected        QIICR      SEG
# 2   AX T2 FSE Glioma Segmentation Corrected        QIICR      SEG
# 3            AX T1 POST Glioma Segmentation        QIICR      SEG
# 4  AX T1 POST Glioma Segmentation Corrected        QIICR      SEG
# 5                 AX T1 Glioma Segmentation        QIICR      SEG
# 6              AX FLAIR Glioma Segmentation        QIICR      SEG
# 7             AX T2 FSE Glioma Segmentation        QIICR      SEG
#
#          SOP Class Name                 SOP Class UID  Number of Images  \
# 0  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 1  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 2  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 3  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 4  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 5  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 6  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
# 7  Segmentation Storage  1.2.840.10008.5.1.4.1.1.66.4                 1
#
#    File Size                                      File Location  \
# 0  596.64 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 1  596.64 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 2  596.64 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 3  596.62 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 4  596.64 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 5  596.62 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 6  596.62 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# 7  596.62 KB  .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
#
#         Download Timestamp
# 0  2021-07-01T23:58:55.447
# 1  2021-07-01T23:58:55.516
# 2   2021-07-01T23:58:57.49
# 3   2021-07-01T23:58:57.58
# 4  2021-07-01T23:58:59.453
# 5  2021-07-01T23:59:00.057
# 6  2021-07-01T23:59:00.258
# 7  2021-07-01T23:59:01.417

# %%
1. создаем список инстансов с метаданных с коррекцией
2. создаем список инстансов из папки
3. сравниваем, чтобы все элементы из папки были в метаданных
4. пишем кого нет и ID

# %%
metadata = metadata[metadata['Series Description'].str.find('Corrected') > 0]

# %%
temp_uid
# Out:
# '1.3.6.1.4.1.14519.5.2.1.8862.4001.119873216352344754496678099313'

# %%
temp_uid
# Out:
# '1.3.6.1.4.1.14519.5.2.1.8862.4001.119873216352344754496678099313'

# %%
list_uids_meta
# Out:
# []

# %%
gbm_paths[gbm_paths['ID'] == 'TCGA-08-0509'].values
# Out:
# array([[53, 'TCGA-08-0509',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/1.000000-FMPSPGR SAG-19386',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/2.000000-3DSPGR AXIAL-93298',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/3.000000-3DFSE AXIAL-99672',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/4.000000-FLAIR AXIAL-76805']],
#       dtype=object)

# %%
modality = ['/T1/', '/CT1/', '/T2/', '/FLAIR/']
for i in list_masks:
    
    list_uids_meta = list(metadata['Study UID'][(metadata['Subject ID'] == i)])
    
    for j in modality:
        temp_list = os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/' + i + j)
        temp_uid = dcmread('/anvar/public_datasets/preproc_study/gbm/dicom/'+ i + j + temp_list[1]).StudyInstanceUID
        if not temp_uid in list_uids_meta:
            print('problems ', i, j, temp_uid)
# Out:
# problems  TCGA-08-0509 /T1/ 1.3.6.1.4.1.14519.5.2.1.7695.4001.292568156105181015740272479103
# problems  TCGA-08-0509 /CT1/ 1.3.6.1.4.1.14519.5.2.1.7695.4001.292568156105181015740272479103
# problems  TCGA-08-0509 /T2/ 1.3.6.1.4.1.14519.5.2.1.7695.4001.292568156105181015740272479103
# problems  TCGA-08-0509 /FLAIR/ 1.3.6.1.4.1.14519.5.2.1.7695.4001.292568156105181015740272479103
# problems  TCGA-12-3650 /T1/ 1.3.6.1.4.1.14519.5.2.1.8862.4001.853973730099261399255070895330
# problems  TCGA-12-3650 /CT1/ 1.3.6.1.4.1.14519.5.2.1.8862.4001.853973730099261399255070895330
# problems  TCGA-12-3650 /T2/ 1.3.6.1.4.1.14519.5.2.1.8862.4001.853973730099261399255070895330
# problems  TCGA-12-3650 /FLAIR/ 1.3.6.1.4.1.14519.5.2.1.8862.4001.853973730099261399255070895330
# problems  TCGA-02-0070 /T1/ 1.3.6.1.4.1.14519.5.2.1.1706.4001.288983046313649223240718848290
# problems  TCGA-02-0070 /CT1/ 1.3.6.1.4.1.14519.5.2.1.1706.4001.288983046313649223240718848290
# problems  TCGA-02-0070 /T2/ 1.3.6.1.4.1.14519.5.2.1.1706.4001.288983046313649223240718848290
# problems  TCGA-02-0070 /FLAIR/ 1.3.6.1.4.1.14519.5.2.1.1706.4001.288983046313649223240718848290
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3397410/3057512889.py in <module>
#       5
#       6     for j in modality:
# ----> 7         temp_list = os.listdir('/anvar/public_datasets/preproc_study/gbm/dicom/' + i + j)
#       8         temp_uid = dcmread('/anvar/public_datasets/preproc_study/gbm/dicom/'+ i + j + temp_list[1]).StudyInstanceUID
#       9         if not temp_uid in list_uids_meta:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/anvar/public_datasets/preproc_study/gbm/dicom/license.html/T1/'

# %%
gbm_paths[gbm_paths['ID'] == 'TCGA-08-0509'].values
# Out:
# array([[53, 'TCGA-08-0509',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/1.000000-FMPSPGR SAG-19386',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/2.000000-3DSPGR AXIAL-93298',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/3.000000-3DFSE AXIAL-99672',
#         ' manifest-21CCx8fx964169794518489879/TCGA-GBM/TCGA-08-0509/11-13-1997-MSTEALTH-79103/4.000000-FLAIR AXIAL-76805']],
#       dtype=object)

# %%
import ants
for i in ['TCGA-08-0509', 'TCGA-12-3650', 'TCGA-02-0070']:
    print(i)
    try:
        t1 = ants.image_read(base_dir + i + '/T1.nii.gz')
        ants.plot(t1)
        t1c = ants.image_read(base_dir + i + '/CT1.nii.gz')
        ants.plot(t1c)
        t2 = ants.image_read(base_dir + i + '/T2.nii.gz')
        ants.plot(t2)
        flair = ants.image_read(base_dir + i + '/FLAIR.nii.gz')
        ants.plot(flair)
    except Exception as e:
        print(e)
        pass
# Out:
# TCGA-08-0509
# TCGA-12-3650
# TCGA-02-0070

# %%
metadata.iloc[0]
# Out:
# Series UID              1.2.276.0.7230010.3.1.3.8323329.363456.1540933...
# Collection                                                       TCGA-GBM
# 3rd Party Analysis                                                    yes
# Data Description URI           https://doi.org/10.7937/TCIA.2018.ow6ce3ml
# Subject ID                                                   TCGA-02-0006
# Study UID               1.3.6.1.4.1.14519.5.2.1.1706.4001.149500105036...
# Study Description                                 MRI BRAIN W WO CONTRAMR
# Study Date                                                     08-23-1996
# Series Description                    AX T1 Glioma Segmentation Corrected
# Manufacturer                                                        QIICR
# Modality                                                              SEG
# SOP Class Name                                       Segmentation Storage
# SOP Class UID                                1.2.840.10008.5.1.4.1.1.66.4
# Number of Images                                                        1
# File Size                                                       596.64 KB
# File Location           .\TCGA-GBM\TCGA-02-0006\08-23-1996-MRI BRAIN W...
# Download Timestamp                                2021-07-01T23:58:55.447
# Name: 0, dtype: object

# %% [markdown]
# ### delete wrong namings

# %%
for i in glob.glob(base_dir +'/*/*real*'):
    os.remove(i)

# %%
glob.glob(base_dir +'/*/*')
# Out:
# ['/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0086/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0102/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0059/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0069/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2624/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0182/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0360/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0006/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-2631/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1094/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-2570/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0119/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0145/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0509/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5408/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0116/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0188/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6661/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0047/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-3650/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-3650/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-3650/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-3650/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-3650/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-3650/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0064/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1825/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0162/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0033/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0359/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0054/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0184/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1601/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5413/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6191/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0075/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0177/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/FLAIR_Eq_1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0154/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0179/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5951/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1598/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0616/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0070/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1084/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0829/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4932/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0068/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6282/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0385/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-1098/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0512/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0512/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0512/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0512/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0512/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0389/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1794/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-1789/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0009/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0122/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0355/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-6389/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0190/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0192/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0027/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0137/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-12-0776/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6657/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0176/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0356/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6662/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0522/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-1802/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5960/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0390/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-1456/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0158/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0139/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0238/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4935/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-14-3477/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0106/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0644/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-0963/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0187/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6664/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6663/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6285/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-4934/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0087/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0392/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0085/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0185/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0130/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0240/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0034/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0149/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0011/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0138/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6280/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5954/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6193/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0164/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-5417/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-19-5958/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-76-6656/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0646/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0046/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-06-0142/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-02-0037/FLAIR.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/T2.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/FLAIR.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/CT1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/T1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/T2.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/T1.json',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/CT1.nii.gz',
#  '/anvar/public_datasets/preproc_study/gbm/orig/TCGA-08-0520/FLAIR.json']

# %% [markdown]
# ## 2. LGG repository

# %%
sizes_frame['t1c_z'].min(), sizes_frame['t1c_z'].max()
# Out:
# (15, 216)

# %%
tcia_lgg_raw = '/anvar/public_datasets/tcia/manifest-25ZdsnMy5264093150469993200/TCGA-LGG/TCGA-CS-5390'
