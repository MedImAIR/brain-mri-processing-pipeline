# %%
import os, sys
import numpy as np
import ants
import argparse
import shutil
import logging
import subprocess
import tqdm
import matplotlib.pyplot as plt 
import pandas as pd
from dpipe.im.visualize import slice3d

# %%
len(os.listdir('/anvar/private_datasets/glioma_burdenko/dcm2nii_BURDENKO_BASELINE_PUBLISH'))
# Out:
# 181

# %%
import glob

# %%
os.listdir('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/705_18_4/')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'T1.nii.gz',
#  'mask_GTV_FLAIR.nii.gz',
#  'CT1.nii.gz']

# %%
os.listdir('/anvar/public_datasets/preproc_study/bgpd/')
# Out:
# ['orig', '5_ss_shared', '2a_interp', '4a_resamp', '1_reg', '6_hist']

# %%
for patient in tqdm.tqdm(os.listdir('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/')):
    if patient == 'logging.txt':
        pass
    for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
        img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/orig/{}/{}'.format(patient, modality))

        if not img.sum() > 0:
            print(patient,modality, 'Amount of nans:', np.shape(np.argwhere(np.isnan(img.numpy()))))
# Out:
#  92%|█████████▏| 166/181 [04:48<00:26,  1.74s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3570431/530305373.py in <module>
#       3         pass
#       4     for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
# ----> 5         img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/orig/{}/{}'.format(patient, modality))
#       6
#       7         if not img.sum() > 0:
#
# ~/miniconda3/lib/python3.9/site-packages/ants/core/ants_image_io.py in image_read(filename, dimension, pixeltype, reorient)
#     513         filename = os.path.expanduser(filename)
#     514         if not os.path.exists(filename):
# --> 515             raise ValueError("File %s does not exist!" % filename)
#     516
#     517         hinfo = image_header_info(filename)
#
# ...

# %%
for patient in tqdm.tqdm(os.listdir('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/')[167:]):
    if patient == 'logging.txt':
        pass
    for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
        img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/orig/{}/{}'.format(patient, modality))

        if not img.sum() > 0:
            print(patient,modality, 'Amount of nans:', np.shape(np.argwhere(np.isnan(img.numpy()))))
# Out:
# 100%|██████████| 14/14 [00:32<00:00,  2.35s/it]

# %%
for patient in tqdm.tqdm(os.listdir('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/')):
    if patient == 'logging.txt':
        pass
    for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
        img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/orig/{}/{}'.format(patient, modality))

        if not img.sum() > 0:
            print(patient,modality, 'Amount of nans:', np.shape(np.argwhere(np.isnan(img.numpy()))))

# %%
for patient in tqdm.tqdm(os.listdir('/anvar/public_datasets/preproc_study/bgpd/1_reg/')[167:]):
    if patient == 'logging.txt':
        pass
    for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
        img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/orig/{}/{}'.format(patient, modality))

        if not img.sum() > 0:
            print(patient,modality, 'Amount of nans:', np.shape(np.argwhere(np.isnan(img.numpy()))))
# Out:
# 100%|██████████| 14/14 [00:32<00:00,  2.33s/it]

# %%
for patient in tqdm.tqdm(os.listdir('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/')):
    if patient != 'logging.txt':
        for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
            img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/{}/{}'.format(patient, modality))

            if not img.sum() > 0:
                print(patient,modality, 'Amount of nans:', np.shape(np.argwhere(np.isnan(img.numpy()))))
# Out:
#  15%|█▍        | 27/181 [00:57<05:25,  2.11s/it]
# 705_18_4 T1.nii.gz Amount of nans: (17, 3)
#  16%|█▌        | 29/181 [01:01<05:20,  2.11s/it]
# Patient_48417 T2.nii.gz Amount of nans: (19930, 3)
#  19%|█▉        | 35/181 [01:15<05:12,  2.14s/it]
# 875_18_4 CT1.nii.gz Amount of nans: (1, 3)
#  62%|██████▏   | 112/181 [04:15<02:57,  2.58s/it]
# Patient_120115 CT1.nii.gz Amount of nans: (2, 3)
# 100%|██████████| 181/181 [06:39<00:00,  2.21s/it]

# %%
for patient in ['705_18_4', '875_18_4', 'Patient_1001316', 'Patient_120115', 'Patient_48417']:
    for modality in ['T1.nii.gz','T2.nii.gz','FLAIR.nii.gz','CT1.nii.gz','mask_GTV_FLAIR.nii.gz']:
        img = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/{}/{}'.format(patient, modality))

        if not img.sum() > 0:
            print(patient,modality, 'Amount of nans:', np.shape(np.argwhere(np.isnan(img.numpy()))))
#     ants.plot(img)
# Out:
# 705_18_4 T1.nii.gz Amount of nans: (17, 3)
# 875_18_4 CT1.nii.gz Amount of nans: (1, 3)
# Patient_120115 CT1.nii.gz Amount of nans: (2, 3)
# Patient_48417 T2.nii.gz Amount of nans: (19930, 3)

# %%
img_4a_resamp = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/4a_resamp/{}/{}'.format('Patient_48417', 'T2.nii.gz'))

# %%
img_1_reg = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/1_reg/{}/{}'.format('Patient_48417', 'T2.nii.gz'))

# %%
np.shape(np.argwhere(np.isnan(img_1_reg.numpy())))
# Out:
# (0, 3)

# %%
slice3d(img_1_reg.numpy())
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='idx', max=26), Output()), _dom_…

# %%
ants.plot(ants.from_numpy(img_fixed_res.numpy()))

# %%
img_fixed_res = ants.resample_image(img_1_reg, (1, 1, 1), False, 0)

# %%
slice3d(img_fixed_res.numpy())
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='idx', max=161), Output()), _dom…

# %%
img_fixed_res
# Out:
# ANTsImage (RPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (240, 240, 162)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (-118.2851, 108.8127, -55.4081)
# 	 Direction  : [ 0.9998  0.0022 -0.0217 -0.     -0.995  -0.0995  0.0218 -0.0995  0.9948]

# %%
img_1_reg.unique()
# Out:
# array([0.0000000e+00, 5.0477238e-06, 7.9944621e-06, ..., 1.3306442e+03,
#        1.3657998e+03, 1.3755852e+03], dtype=float32)

# %%
img_orig.unique()
# Out:
# array([0.000e+00, 1.000e+00, 2.000e+00, ..., 1.374e+03, 1.426e+03,
#        1.444e+03], dtype=float32)

# %%
img_orig = ants.image_read('/anvar/public_datasets/preproc_study/bgpd/orig/{}/{}'.format('Patient_48417', 'T2.nii.gz'))

# %%
slice3d(img_orig.numpy())
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='idx', max=26), Output()), _dom_…

# %%
slice3d(img_4a_resamp.numpy())
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='idx', max=161), Output()), _dom…

# %%
ants.plot(ants.from_numpy(img_nan_to_num))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_3570431/2523050117.py in <module>
# ----> 1 ants.plot(ants.from_numpy(img_nan_to_num))
#
# ~/miniconda3/lib/python3.9/site-packages/ants/viz/plot.py in plot(image, overlay, blend, alpha, cmap, overlay_cmap, overlay_alpha, cbar, cbar_length, cbar_dx, cbar_vertical, axis, nslices, slices, ncol, slice_buffer, black_bg, bg_thresh_quant, bg_val_quant, domain_image_map, crop, scale, reverse, title, title_fontsize, title_dx, title_dy, filename, dpi, figsize, reorient, resample)
#    2250         raise ValueError("image argument must be an ANTsImage")
#    2251
# -> 2252     assert image.sum() > 0, "Image must be non-zero"
#    2253
#    2254     if (image.pixeltype not in {"float", "double"}) or (image.is_rgb):
#
# AssertionError: Image must be non-zero

# %%
plt.imshow(img.numpy()[:,:, 70])

# %%
img_nan_to_num = np.nan_to_num(img.numpy(), nan=0.0)

# %%
plt.imshow(img_nan_to_num[:,:, 90])

# %%
plt.imshow(img.numpy()[:,:, 70])

# %%
np.argwhere(np.isnan(img.numpy()))
# Out:
# array([[  0,   2, 135],
#        [  0,   2, 151],
#        [  0,   3, 107],
#        ...,
#        [239, 228,  90],
#        [239, 228, 115],
#        [239, 229, 103]])

# %%
np.isinf(img.numpy()).all()
# Out:
# False

# %%
np.shape(np.argwhere(np.isnan(img.numpy())))
# Out:
# (0, 3)

# %%
os.listdir('/anvar/private_datasets/brats_pipeline_out/Patient_50214/T1_to_SRI_brain.nii.gz')
# Out:
# ['T2_rai.nii.gz',
#  'dmOut_tumor',
#  'FL_rai.nii.gz',
#  'FL_to_T1CE.mat',
#  'gost_gtv_to_ref.nii.gz',
#  'T1CE_rai_n4.nii.gz',
#  'brainTumorMask_SRI.nii.gz',
#  'T2_raw.nii.gz',
#  'T2_to_SRI.nii.gz',
#  'seg_to_ref.nii.gz',
#  'T2_rai_n4.nii.gz',
#  'T1_rai_n4.nii.gz',
#  'T1_to_T1CE.mat',
#  'T1_raw.nii.gz',
#  'FL_raw.nii.gz',
#  'T1CE_raw.nii.gz',
#  'FL_rai_n4.nii.gz',
#  'T2_to_SRI_brain.nii.gz',
#  'T1CE_to_SRI.mat',
#  'T2_to_T1CE.mat',
#  'T1_rai.nii.gz',
#  'T1_to_SRI_brain.nii.gz',
#  'T1_to_SRI.nii.gz',
#  'check_gost_gtv_to_ref.nii.gz',
#  'brainMask_SRI.nii.gz',
#  'dmOut_skull',
#  'T1CE_to_SRI_brain.nii.gz',
#  'T1CE_rai.nii.gz',
#  'FL_to_SRI.nii.gz',
#  'FL_to_SRI_brain.nii.gz',
#  'T1CE_to_SRI.nii.gz']

# %%
len(glob.glob('/anvar/private_datasets/brats_pipeline_out/*/T1_to_SRI_brain.nii.gz'))
# Out:
# 370

# %%
os.listdir('/anvar/private_datasets/brats_pipeline_out/Patient_50214/')
# Out:
# ['T2_rai.nii.gz',
#  'dmOut_tumor',
#  'FL_rai.nii.gz',
#  'FL_to_T1CE.mat',
#  'gost_gtv_to_ref.nii.gz',
#  'T1CE_rai_n4.nii.gz',
#  'brainTumorMask_SRI.nii.gz',
#  'T2_raw.nii.gz',
#  'T2_to_SRI.nii.gz',
#  'seg_to_ref.nii.gz',
#  'T2_rai_n4.nii.gz',
#  'T1_rai_n4.nii.gz',
#  'T1_to_T1CE.mat',
#  'T1_raw.nii.gz',
#  'FL_raw.nii.gz',
#  'T1CE_raw.nii.gz',
#  'FL_rai_n4.nii.gz',
#  'T2_to_SRI_brain.nii.gz',
#  'T1CE_to_SRI.mat',
#  'T2_to_T1CE.mat',
#  'T1_rai.nii.gz',
#  'T1_to_SRI_brain.nii.gz',
#  'T1_to_SRI.nii.gz',
#  'check_gost_gtv_to_ref.nii.gz',
#  'brainMask_SRI.nii.gz',
#  'dmOut_skull',
#  'T1CE_to_SRI_brain.nii.gz',
#  'T1CE_rai.nii.gz',
#  'FL_to_SRI.nii.gz',
#  'FL_to_SRI_brain.nii.gz',
#  'T1CE_to_SRI.nii.gz']

# %%
# os.mkdir('/anvar/public_datasets/preproc_study/bgpd/orig/')

# %%
os.listdir('/anvar/private_datasets/glioma_burdenko/dcm2nii_BURDENKO_BASELINE_PUBLISH/1360_18')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'T1.nii.gz',
#  'MASK_DICOM',
#  'REF.json',
#  'T1',
#  'T2',
#  'CT1',
#  'T2.json',
#  'T1.json',
#  'mask_GTV_FLAIR.nii.gz',
#  'RTSTRUCT',
#  'REF',
#  'CT1.nii.gz',
#  'mask_GTV_FLAIR.json',
#  'REF.nii.gz',
#  'FLAIR']

# %%
os.listdir('/anvar/private_datasets/glioma_burdenko/dcm2nii_BURDENKO_BASELINE_PUBLISH/Patient_54317/')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'FLAIR_real.json',
#  'CT1.json',
#  'T2_real.json',
#  'MASK_DICOM_CT',
#  'mask_GTV_CT.nii.gz',
#  'T1.nii.gz',
#  'REF.json',
#  'T1',
#  'T2',
#  'mask_GTV_CT.json',
#  'CT1',
#  'T1.json',
#  'T2_real.nii.gz',
#  'mask_GTV_FLAIR.nii.gz',
#  'RTSTRUCT',
#  'REF',
#  'CT1.nii.gz',
#  'CT',
#  'REF.nii.gz',
#  'FLAIR']

# %%
os.listdir('/anvar/private_datasets/glioma_burdenko/dcm2nii_BURDENKO_BASELINE_PUBLISH/Patient_56717/')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'CT1.json',
#  'MASK_DICOM_CT',
#  'mask_GTV_CT.nii.gz',
#  'FLAIR_e6.json',
#  'T1.nii.gz',
#  'REF.json',
#  'T1',
#  'T2',
#  'T1a.nii.gz',
#  'mask_GTV_CT.json',
#  'CT1',
#  'CT1a.nii.gz',
#  'T1.json',
#  'mask_GTV_FLAIR.nii.gz',
#  'RTSTRUCT',
#  'REF',
#  'CT1.nii.gz',
#  'CT',
#  'CT1a.json',
#  'T2_e7.nii.gz',
#  'REF.nii.gz',
#  'FLAIR_e6.nii.gz',
#  'FLAIR',
#  'T2_e7.json',
#  'T1a.json']

# %%
# shutil.rmtree('/anvar/public_datasets/preproc_study/bgpd/orig/Patient_54317')

# %%
source_dir = '/anvar/private_datasets/glioma_burdenko/dcm2nii_BURDENKO_BASELINE_PUBLISH/'
save_dir = '/anvar/public_datasets/preproc_study/bgpd/orig/'
for patient in os.listdir(source_dir):
    
    try:
#         os.mkdir(save_dir  + patient)
        shutil.copyfile(source_dir   + patient + '/T1.nii.gz', save_dir  + patient + '/T1.nii.gz')
        shutil.copyfile(source_dir   + patient + '/CT1.nii.gz', save_dir  + patient + '/CT1.nii.gz')
        shutil.copyfile(source_dir   + patient + '/FLAIR.nii.gz', save_dir  + patient + '/FLAIR.nii.gz')
        shutil.copyfile(source_dir   + patient + '/T2.nii.gz', save_dir  + patient + '/T2.nii.gz')
        shutil.copyfile(source_dir   + patient + '/mask_GTV_FLAIR.nii.gz', save_dir  + patient + '/mask_GTV_FLAIR.nii.gz')
        assert (len(os.listdir(save_dir  + patient)) == 5)
    except Exception as e:
        print(e)

# %%
len(os.listdir('/anvar/public_datasets/preproc_study/bgpd/5_ss_shared'))
# Out:
# 181

# %%
os.listdir('/anvar/public_datasets/preproc_study/bgpd/5_ss_shared/Patient_1000314/')
# Out:
# ['T2.nii.gz',
#  'FLAIR.nii.gz',
#  'T1.nii.gz',
#  'mask_GTV_FLAIR.nii.gz',
#  'CT1.nii.gz',
#  'FLAIR_mask.nii.gz']

# %%
os.listdir('/anvar/public_datasets/EGD/EGD-0517/MR_EGD-0517/scans/1_T1-T1/resources/NIFTI/files/T1.nii.gz')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /tmp/ipykernel_3570431/540550722.py in <module>
# ----> 1 os.listdir('/anvar/public_datasets/EGD/EGD-0517/MR_EGD-0517/scans/1_T1-T1/resources/NIFTI/files/T1.nii.gz')
#
# NotADirectoryError: [Errno 20] Not a directory: '/anvar/public_datasets/EGD/EGD-0517/MR_EGD-0517/scans/1_T1-T1/resources/NIFTI/files/T1.nii.gz'

# %%
len(os.listdir('/anvar/public_datasets/EGD/'))
# Out:
# 782

# %%
import ants

# %%
ants.plot(
    ants.image_read('/anvar/private_datasets/brats_pipeline_out/Patient_50214/T1_to_SRI_brain.nii.gz')
)

# %%
ants.plot(
    ants.image_read('/anvar/public_datasets/preproc_study/bgpd/5_ss_shared/Patient_1000314/FLAIR_mask.nii.gz')
)

# %% [markdown]
# ### Check sizes

# %%
import ants
import pandas as pd
sizes_frame = pd.DataFrame(columns = ['id','fl_x', 'fl_y', 'fl_z', 't1c_x', 't1c_y', 't1c_z'])
import numpy as np
for i in os.listdir(source_dir):
    try:
        fl_size = np.shape(ants.image_read(save_dir + i + '/FLAIR.nii.gz').numpy())
        t1c_size = np.shape(ants.image_read(save_dir + i + '/CT1.nii.gz').numpy())
        sizes_frame = sizes_frame.append(
        {'id': i,
        'fl_x':fl_size[0],
        'fl_y':fl_size[1],
        'fl_z':fl_size[2],
        't1c_x':t1c_size[0],
        't1c_y':t1c_size[1],
        't1c_z':t1c_size[2]}, ignore_index=True
        )
    except:
        pass

# %%
sizes_frame['t1c_z'].hist()
# Out:
# <AxesSubplot:>

# %%
len(sizes_frame[(sizes_frame['fl_z'] >= sizes_frame['t1c_z'])])
# Out:
# 90

# %%
len(sizes_frame[(sizes_frame['fl_z'] <= sizes_frame['t1c_z'])])
# Out:
# 138

# %%
sizes_frame_t1 = pd.DataFrame(columns = ['id','t1_x', 't1_y', 't1_z', 't1c_x', 't1c_y', 't1c_z'])
import numpy as np
for i in os.listdir(source_dir):
    try:
        t1_size = np.shape(ants.image_read(save_dir + i + '/T1.nii.gz').numpy())
        t1c_size = np.shape(ants.image_read(save_dir + i + '/CT1.nii.gz').numpy())
        sizes_frame_t1 = sizes_frame_t1.append(
        {'id': i,
        't1_x':t1_size[0],
        't1_y':t1_size[1],
        't1_z':t1_size[2],
        't1c_x':t1c_size[0],
        't1c_y':t1c_size[1],
        't1c_z':t1c_size[2]}, ignore_index=True
        )
    except:
        pass

# %%
###
